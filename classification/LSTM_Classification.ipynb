# %% [markdown]
# # Bitcoin Recurrent Neural Network
# - Abstract
# - Long short-term memory(LSTM)

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from visdom import Visdom
viz = Visdom()

# %%
import unidecode
import string
import random
import re
import time, math
from utils2 import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2) Hyperparameter

# %%
num_epochs = 5000
hidden_size = 100
output_size=1
batch_size =1
num_layers = 3
lr = 0.002
NUM_STEPS = 500
chunk_len=200
path = '../data/bitstamp.csv'

# %%
# train Parameters
seq_length = 200
sub_seq_length = 150
data_dim = 18
hidden_dim = 10
output_dim = 1
learning_rate = 0.01
iterations = 101
plot_name = 'LSTM_new_01'

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ### 2) Get data

# %%
data = data_loading(path)

# %%
len(data)
# Out:
# 2171

# %%
data[1:,-1].shape
# Out:
# (2170,)

# %%
label=np.zeros((2170,2))

# %%
for j in range(len[label]):
    if data[j,-1]-data[j,-1]
    label[j][0]

# %% [markdown]
# ### 3) Chunk into input & label

# %%
def random_chunk():
    start_index = random.randint(0, len(data) - chunk_len)
    end_index = start_index + chunk_len + 1
    return data[start_index:end_index]

print(random_chunk().shape)
# Out:
# (501, 18)

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = torch.from_numpy(chunk[:-1])
    target = torch.from_numpy(chunk[1:,-1])
    return Variable(inp).cuda(), Variable(target).cuda()

# %% [markdown]
# ## 3. Model & Optimizer
# ### 1) Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=3):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.encoder = nn.Linear(input_size, hidden_size)
        self.rnn = nn.LSTM(hidden_size,hidden_size,num_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
    def forward(self, input, hidden,cell):
        out = self.encoder(input.view(1,-1))
        #out = self.encoder(input)
        out,(hidden,cell) = self.rnn(out.view(1,1,-1),(hidden,cell))
        out = self.decoder(out.view(batch_size,-1))
        return out,hidden,cell
    def init_hidden(self):
        hidden = Variable(torch.zeros(num_layers,batch_size,hidden_size)).cuda()
        cell = Variable(torch.zeros(num_layers,batch_size,hidden_size)).cuda()
        return hidden,cell
model = RNN(data.shape[1], hidden_size, output_size, num_layers).cuda()

# %% [markdown]
# ### 2) Loss & Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_func = nn.MSELoss()

# %% [markdown]
# ### 3) Training

# %%
for i in range(num_epochs):
    inp , label = random_training_set()
    hidden,cell = model.init_hidden()
    loss = 0
    optimizer.zero_grad()
    for j in range(chunk_len-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden,cell = model(x,hidden,cell)
        loss += loss_func(y,y_)
    loss.backward()
    optimizer.step()
    if i % 100 == 0:
        print(i)
        print("\n",loss/chunk_len,"\n")
# Out:
# 0
#
#  Variable containing:
#  39.6774
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 100
#
#  Variable containing:
#  4.3082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 200
#
#  Variable containing:
#  0.9978
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 300
#
#  Variable containing:
#  0.9757
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 400
#
#  Variable containing:
#  0.5862
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 500
#
#  Variable containing:
#  0.6631
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 600
#
#  Variable containing:
#  0.1988
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 700
#
#  Variable containing:
# 1.00000e-02 *
#   8.4545
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 800
#
#  Variable containing:
#  0.3938
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 900
#
#  Variable containing:
#  0.5026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1000
#
#  Variable containing:
#  0.1034
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1100
#
#  Variable containing:
# 1.00000e-02 *
#   8.9844
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1200
#
#  Variable containing:
#  0.4772
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1300
#
#  Variable containing:
#  0.1925
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1400
#
#  Variable containing:
#  0.1443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1500
#
#  Variable containing:
#  0.2056
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1600
#
#  Variable containing:
#  0.4570
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1700
#
#  Variable containing:
#  0.4948
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1800
#
#  Variable containing:
# 1.00000e-02 *
#   8.5415
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1900
#
#  Variable containing:
#  0.2735
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2000
#
#  Variable containing:
#  0.1324
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2100
#
#  Variable containing:
#  0.4766
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2200
#
#  Variable containing:
#  0.1031
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2300
#
#  Variable containing:
#  0.3772
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2400
#
#  Variable containing:
# 1.00000e-02 *
#   6.9001
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2500
#
#  Variable containing:
# 1.00000e-02 *
#   4.0567
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2600
#
#  Variable containing:
# 1.00000e-02 *
#   6.3800
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2700
#
#  Variable containing:
# 1.00000e-02 *
#   3.9284
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2800
#
#  Variable containing:
# 1.00000e-02 *
#   4.0958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2900
#
#  Variable containing:
# 1.00000e-02 *
#   6.6111
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3000
#
#  Variable containing:
# 1.00000e-02 *
#   9.6437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3100
#
#  Variable containing:
#  0.1571
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3200
#
#  Variable containing:
# 1.00000e-02 *
#   4.7126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3300
#
#  Variable containing:
# 1.00000e-02 *
#   5.1427
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3400
#
#  Variable containing:
#  0.1583
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3500
#
#  Variable containing:
# 1.00000e-02 *
#   6.2577
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3600
#
#  Variable containing:
# 1.00000e-02 *
#   7.2558
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3700
#
#  Variable containing:
#  0.1514
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3800
#
#  Variable containing:
# 1.00000e-02 *
#   6.0912
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3900
#
#  Variable containing:
# 1.00000e-02 *
#   5.9038
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4000
#
#  Variable containing:
#  0.1752
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4100
#
#  Variable containing:
#  0.1105
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4200
#
#  Variable containing:
# 1.00000e-02 *
#   6.0856
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4300
#
#  Variable containing:
# 1.00000e-02 *
#   4.4718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4400
#
#  Variable containing:
#  0.1451
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4500
#
#  Variable containing:
# 1.00000e-02 *
#   7.1678
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4600
#
#  Variable containing:
# 1.00000e-02 *
#   6.6077
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4700
#
#  Variable containing:
#  0.1883
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4800
#
#  Variable containing:
# 1.00000e-02 *
#   4.4414
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4900
#
#  Variable containing:
#  0.3852
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %% [markdown]
# ### 4. Inference

# %%
def inference_set():    
    inp = torch.from_numpy(data[:-1])
    target = torch.from_numpy(data[1:,-1])
    return Variable(inp).cuda(), Variable(target).cuda()

# %%
aa = data[:-1]
aa.shape
# Out:
# (2170, 18)

# %%
def inference():
    inp , label = inference_set()
    hidden,cell = model.init_hidden()
    optimizer.zero_grad()
    real=[]
    predict=[]
    for j in range(len(inp)-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden,cell = model(x,hidden,cell)
        #print(y_.cpu().data.numpy()[0])
        real.append(y_.cpu().data.numpy()[0])
        #print(y.cpu().data.numpy()[0][0])
        predict.append(y.cpu().data.numpy()[0][0])
        if j > 1000:
            print(j)
            print(hidden[0])
            print(y)
        #predict.np.append(y.cpu())
    return real , predict

# %%
real, predict = inference()
# Out:
# 1001
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1002
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1003
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1004
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1005
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1006
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1007
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1008
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1009
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1010
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1011
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1012
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1013
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1014
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1015
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1016
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1017
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1018
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1019
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1020
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1021
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1022
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1023
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1024
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1025
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1026
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1027
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1028
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1029
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1030
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1031
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1032
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1033
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1034
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1035
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1036
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1037
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1038
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1039
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1040
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1041
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1042
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  0.0000  0.0000  0.7616 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -0.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.7616
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000  0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  0.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.7616  0.0000  1.0000  0.0000  1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  6.6231
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 1043
# Variable containing:
#
# Columns 0 to 9
#  0.7616  0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.0000 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  0.7616 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# ...
#
# Variable containing:
#  8.2338
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2155
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000 -0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2684
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2156
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000 -0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2695
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2157
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2699
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2158
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000 -0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2700
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2159
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000 -0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2700
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2160
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2563
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2161
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2553
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2162
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  1.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.2546
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2163
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.1409
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2164
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.1258
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2165
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.7616  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -1.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.1009
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2166
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.0680
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2167
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.0620
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# 2168
# Variable containing:
#
# Columns 0 to 9
#  0.0000 -0.0000 -1.0000  0.0000  0.0000  0.7616  0.7616  0.7616 -0.0000  0.0000
#
# Columns 10 to 19
#  0.0000  0.0000  0.0000  1.0000 -0.0000 -0.7616 -0.7616  0.0000 -0.7616  0.0000
#
# Columns 20 to 29
# -0.0000  0.0000  1.0000  0.0000  0.0000 -0.0000  1.0000 -1.0000 -1.0000 -0.0000
#
# Columns 30 to 39
# -0.7616 -0.7616  0.0000  0.0000  0.0000 -0.0000 -1.0000 -0.0000  1.0000  0.0000
#
# Columns 40 to 49
# -1.0000 -0.0000  0.0000 -1.0000  0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000
#
# Columns 50 to 59
# -0.0000  0.0000  0.0000  0.0000  1.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
#
# Columns 60 to 69
#  0.0000  0.0000 -0.0000  0.0000  0.7616 -1.0000 -0.0000  0.0000 -0.0000  0.0000
#
# Columns 70 to 79
#  0.0000  0.0000  0.0000  0.0000  0.7616  0.0000 -0.0000 -0.7616  0.0000 -1.0000
#
# Columns 80 to 89
#  0.0000 -0.0000  0.0000  0.0000  1.0000 -0.0000  1.0000  1.0000 -0.0000  0.0000
#
# Columns 90 to 99
#  0.0000  0.0000  1.0000  0.0000 -1.0000  0.0000  0.7616  0.0000  0.0000  0.0000
# [torch.cuda.FloatTensor of size 1x100 (GPU 0)]
#
# Variable containing:
#  8.0567
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]

# %%
predict[1000:1050]
# Out:
# [6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279,
#  6.6231279]

# %%
plt.figure
plt.plot(real)
plt.plot(predict)
plt.show()
