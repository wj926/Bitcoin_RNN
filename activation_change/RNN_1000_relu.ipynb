# %% [markdown]
# # Bitcoin Recurrent Neural Network
# - Recent 1000
# - Long short-term memory(LSTM)

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from visdom import Visdom
viz = Visdom()

# %%
import string
import random
import re
import time, math
from utils2 import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2) Hyperparameter

# %%
num_epochs = 5000
hidden_size = 30
output_size=1
batch_size =1
num_layers = 3
lr = 0.002
NUM_STEPS = 500
chunk_len=200
num_layers = 1
recent_num =1000
path = '../data/bitstamp.csv'

# %%
# train Parameters
seq_length = 200
sub_seq_length = 150
data_dim = 18
hidden_dim = 10
output_dim = 1
learning_rate = 0.01
iterations = 101
plot_name = 'LSTM_new_01'

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ### 2) Get data

# %%
data_raw = data_loading(path)

# %%
data_raw[-1]
# Out:
# array([  2.35227598e+04,   2.42228105e+04,   9.98175250e+05,
#          1.38100004e+01,   5.27782900e+06,   8.50000024e-01,
#          6.78738750e+06,   2.36772000e+05,   2.27242000e+05,
#          4.77000008e+01,   3.28761011e+03,   1.28863000e+03,
#          1.13500004e+01,   7.38174023e+03,   6.66230011e+00,
#          1.09690804e+02,   9.67999995e-01,   8.26722336e+00], dtype=float32)

# %%
data = data_raw[-recent_num:,:]

# %%
data.shape
# Out:
# (1000, 18)

# %% [markdown]
# ### 3) Chunk into input & label

# %%
def random_chunk():
    start_index = random.randint(0, len(data) - chunk_len)
    end_index = start_index + chunk_len + 1
    return data[start_index:end_index]

print(random_chunk().shape)
# Out:
# (201, 18)

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = torch.from_numpy(chunk[:-1])
    target = torch.from_numpy(chunk[1:,-1])
    return Variable(inp).cuda(), Variable(target).cuda()

# %% [markdown]
# ## 3. Model & Optimizer
# ### 1) Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=num_layers):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.encoder = nn.Linear(input_size, hidden_size)
        self.rnn = nn.RNN(hidden_size,hidden_size,num_layers, nonlinearity ='relu')
        self.decoder = nn.Linear(hidden_size, output_size)
    def forward(self, input, hidden):
        out = self.encoder(input.view(1,-1))
        #out = self.encoder(input)
        out,hidden, = self.rnn(out.view(1,1,-1),hidden)
        out = self.decoder(out.view(batch_size,-1))
        return out,hidden
    def init_hidden(self):
        hidden = Variable(torch.zeros(num_layers,batch_size,hidden_size)).cuda()
        return hidden
model = RNN(data.shape[1], hidden_size, output_size, num_layers).cuda()

# %% [markdown]
# ### 2) Loss & Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_func = nn.MSELoss()

# %% [markdown]
# ### 3) Training

# %%
for i in range(num_epochs):
    inp , label = random_training_set()
    hidden = model.init_hidden()
    loss = 0
    optimizer.zero_grad()
    for j in range(chunk_len-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden = model(x,hidden)
        loss += loss_func(y,y_)
    loss.backward()
    optimizer.step()
    if i % 100 == 0:
        print(i)
        print("\n",loss/chunk_len,"\n")
# Out:
# 0
#
#  Variable containing:
#  1.0048e+09
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 100
#
#  Variable containing:
#  7.4281e+06
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 200
#
#  Variable containing:
# 1.00000e+06 *
#   4.5302
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 300
#
#  Variable containing:
# 1.00000e+06 *
#   2.2430
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 400
#
#  Variable containing:
# 1.00000e+06 *
#   2.4433
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 500
#
#  Variable containing:
# 1.00000e+06 *
#   3.5749
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 600
#
#  Variable containing:
#  4.2983e+07
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 700
#
#  Variable containing:
#  1.2342e+06
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 800
#
#  Variable containing:
#  2.6037e+06
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 900
#
#  Variable containing:
# 1.00000e+06 *
#   1.4569
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1000
#
#  Variable containing:
# 1.00000e+06 *
#   2.0866
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1100
#
#  Variable containing:
# 1.00000e+06 *
#   1.5541
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1200
#
#  Variable containing:
# 1.00000e+05 *
#   9.6005
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1300
#
#  Variable containing:
#  2.4188e+07
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1400
#
#  Variable containing:
# 1.00000e+06 *
#   1.1848
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1500
#
#  Variable containing:
# 1.00000e+05 *
#   3.9563
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1600
#
#  Variable containing:
# 1.00000e+05 *
#   1.9882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1700
#
#  Variable containing:
# 1.00000e+05 *
#   7.3540
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1800
#
#  Variable containing:
# 1.00000e+05 *
#   3.3906
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 1900
#
#  Variable containing:
# 1.00000e+05 *
#   1.1404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2000
#
#  Variable containing:
# 1.00000e+05 *
#   1.5538
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2100
#
#  Variable containing:
# 1.00000e+05 *
#   1.8786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2200
#
#  Variable containing:
# 1.00000e+05 *
#   8.5145
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2300
#
#  Variable containing:
#  75995.7109
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2400
#
#  Variable containing:
#  80749.7344
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2500
#
#  Variable containing:
#  52266.2227
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2600
#
#  Variable containing:
# 1.00000e+05 *
#   1.1257
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2700
#
#  Variable containing:
# 1.00000e+05 *
#   3.4720
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2800
#
#  Variable containing:
# 1.00000e+05 *
#   1.7194
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 2900
#
#  Variable containing:
# 1.00000e+05 *
#   1.5378
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3000
#
#  Variable containing:
#  1.6580e+07
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3100
#
#  Variable containing:
#  4.2786e+05
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3200
#
#  Variable containing:
# 1.00000e+05 *
#   2.4143
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3300
#
#  Variable containing:
# 1.00000e+05 *
#   2.3200
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3400
#
#  Variable containing:
#  53963.8477
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3500
#
#  Variable containing:
# 1.00000e+05 *
#   1.0254
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3600
#
#  Variable containing:
#  93421.8359
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3700
#
#  Variable containing:
#  85851.8750
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3800
#
#  Variable containing:
#  52917.5742
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 3900
#
#  Variable containing:
# 1.00000e+05 *
#   1.3117
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4000
#
#  Variable containing:
#  39322.5156
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4100
#
#  Variable containing:
# 1.00000e+05 *
#   1.6928
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4200
#
#  Variable containing:
#  16389.5957
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4300
#
#  Variable containing:
#  15616.7656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4400
#
#  Variable containing:
#  67241.3594
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4500
#
#  Variable containing:
#  15825.0918
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4600
#
#  Variable containing:
#  17057.6699
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4700
#
#  Variable containing:
#  26392.4648
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4800
#
#  Variable containing:
#  19963.5273
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# 4900
#
#  Variable containing:
#  51773.0938
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %% [markdown]
# ### 4. Inference

# %%
def inference_set():    
    inp = torch.from_numpy(data[:-1])
    target = torch.from_numpy(data[1:,-1])
    return Variable(inp).cuda(), Variable(target).cuda()

# %%
aa = data[:-1]
aa.shape
# Out:
# (999, 18)

# %%
def inference():
    inp , label = inference_set()
    hidden = model.init_hidden()
    optimizer.zero_grad()
    real=[]
    predict=[]
    for j in range(len(inp)-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden = model(x,hidden)
        #print(y_.cpu().data.numpy()[0])
        real.append(y_.cpu().data.numpy()[0])
        #print(y.cpu().data.numpy()[0][0])
        predict.append(y.cpu().data.numpy()[0][0])
        #predict.np.append(y.cpu())
        if j>800:
            print(x)
            print(y_)
            print(y)
            print(hidden)
    return real , predict

# %%
real, predict = inference()
# Out:
# Variable containing:
#  4.3482e+03
#  1.2080e+04
#  9.5794e+05
#  2.1340e+01
#  3.0430e+06
#  9.1000e-01
#  1.9350e+06
#  2.8633e+05
#  2.8134e+05
#  5.3830e+01
#  3.1601e+03
#  1.2185e+03
#  1.0970e+01
#  7.1883e+03
#  6.8698e+00
#  1.1265e+02
#  9.9240e-01
#  6.9236e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9288
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -344.0141
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.3165e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9947e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.1603e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3641e+05  0.0000e+00  1.4603e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.0796e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.0809e+03
#  1.4396e+04
#  9.7920e+05
#  1.6670e+01
#  3.3368e+06
#  1.1300e+00
#  2.0692e+06
#  2.9210e+05
#  2.8691e+05
#  5.3010e+01
#  3.1431e+03
#  1.2300e+03
#  1.1370e+01
#  7.1721e+03
#  6.8630e+00
#  1.1183e+02
#  9.9140e-01
#  6.9288e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9503
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -69.0899
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.9727e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.4402e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.4599e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.5378e+05  0.0000e+00  1.5334e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.1002e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.3721e+03
#  1.5165e+04
#  9.4568e+05
#  1.8280e+01
#  2.6233e+06
#  8.0000e-01
#  1.6948e+06
#  2.3003e+05
#  2.2533e+05
#  5.2170e+01
#  3.1544e+03
#  1.2342e+03
#  1.1290e+01
#  7.1862e+03
#  6.8844e+00
#  1.1239e+02
#  9.9780e-01
#  6.9503e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9524
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -1204.6417
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.7688e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.6200e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.2090e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.0907e+05  0.0000e+00  1.3870e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.2299e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  9.6333e+03
#  2.0292e+04
#  9.6113e+05
#  2.3870e+01
#  3.1689e+06
#  8.1000e-01
#  2.0774e+06
#  3.2527e+05
#  3.2085e+05
#  5.2340e+01
#  3.1481e+03
#  1.2376e+03
#  1.1450e+01
#  7.1888e+03
#  6.8722e+00
#  1.1195e+02
#  9.9530e-01
#  6.9524e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9044
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  193.0528
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  1.9395e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9152e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.7619e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4157e+05  0.0000e+00  1.4348e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.8536e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  2.5150e+04
#  2.7528e+04
#  9.5603e+05
#  1.3030e+01
#  3.0640e+06
#  7.7000e-01
#  2.0025e+06
#  3.0832e+05
#  3.0256e+05
#  5.3000e+01
#  3.1647e+03
#  1.2351e+03
#  1.0880e+01
#  7.2295e+03
#  6.8688e+00
#  1.1343e+02
#  1.0014e+00
#  6.9044e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.8852
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -678.1160
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  1.9970e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.4066e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.5326e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2700e+05  0.0000e+00  1.4977e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.0563e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.0731e+04
#  2.1255e+04
#  9.6755e+05
#  1.6620e+01
#  3.5467e+06
#  6.3000e-01
#  2.1482e+06
#  3.4654e+05
#  3.4014e+05
#  5.3860e+01
#  3.1830e+03
#  1.2344e+03
#  1.0850e+01
#  7.2588e+03
#  6.8784e+00
#  1.1321e+02
#  1.0024e+00
#  6.8852e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  177.7714
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.0054e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.3495e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9872e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.6249e+05  0.0000e+00  1.5465e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.0686e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  4.4725e+03
#  1.0414e+04
#  9.6366e+05
#  1.0430e+01
#  3.1060e+06
#  6.7000e-01
#  1.9148e+06
#  3.0446e+05
#  2.9982e+05
#  5.3860e+01
#  3.1830e+03
#  1.2344e+03
#  1.0850e+01
#  7.2588e+03
#  6.8784e+00
#  1.1321e+02
#  1.0024e+00
#  6.9159e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9101
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -849.8615
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.3846e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.1780e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.0729e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3098e+05  0.0000e+00  1.4926e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.5676e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  2.6840e+03
#  4.0253e+03
#  8.7246e+05
#  1.7150e+01
#  2.9171e+06
#  1.1400e+00
#  1.7921e+06
#  2.6269e+05
#  2.5909e+05
#  5.3860e+01
#  3.1830e+03
#  1.2344e+03
#  1.0850e+01
#  7.2588e+03
#  6.8782e+00
#  1.1392e+02
#  1.0046e+00
#  6.9101e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -278.2166
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.8754e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.7607e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.2898e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3158e+05  0.0000e+00  1.3369e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.5729e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  4.5473e+03
#  5.3158e+03
#  9.1046e+05
#  1.3970e+01
#  2.9591e+06
#  1.5900e+00
#  1.7904e+06
#  2.3818e+05
#  2.3510e+05
#  5.2930e+01
#  3.1990e+03
#  1.2244e+03
#  1.1070e+01
#  7.2789e+03
#  6.8816e+00
#  1.1371e+02
#  1.0057e+00
#  6.9022e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9144
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -133.7852
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.2908e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.1827e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.5790e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4106e+05  0.0000e+00  1.3694e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.3704e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  6.7611e+03
#  6.4959e+03
#  8.8473e+05
#  9.2600e+00
#  3.4208e+06
#  1.1200e+00
#  2.0907e+06
#  2.8829e+05
#  2.8446e+05
#  5.3200e+01
#  3.2161e+03
#  1.2239e+03
#  1.0740e+01
#  7.2686e+03
#  6.8676e+00
#  1.1430e+02
#  1.0063e+00
#  6.9144e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  447.2446
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.0577e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.3991e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.6232e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.6060e+05  0.0000e+00  1.4564e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.8586e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  3.0957e+03
#  4.1130e+03
#  9.4009e+05
#  1.2770e+01
#  3.5467e+06
#  9.9000e-01
#  2.1983e+06
#  3.1508e+05
#  3.1103e+05
#  5.3110e+01
#  3.2155e+03
#  1.2317e+03
#  1.1970e+01
#  7.3024e+03
#  6.8714e+00
#  1.1412e+02
#  1.0048e+00
#  6.9168e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9364
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -1.3681
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.1527e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.4896e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.6139e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.5832e+05  0.0000e+00  1.5711e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.4114e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.9961e+03
#  5.1845e+03
#  9.7411e+05
#  1.9270e+01
#  2.9171e+06
#  9.3000e-01
#  1.8225e+06
#  2.9479e+05
#  2.9132e+05
#  5.3360e+01
#  3.2104e+03
#  1.2400e+03
#  1.1760e+01
#  7.2779e+03
#  6.8536e+00
#  1.1331e+02
#  9.9720e-01
#  6.9364e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9561
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -1082.3621
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.2305e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9252e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.7422e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2014e+05  0.0000e+00  1.4520e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.5748e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  6.0850e+03
#  8.9888e+03
#  9.6908e+05
#  1.1630e+01
#  3.1899e+06
#  9.9000e-01
#  2.0715e+06
#  2.8533e+05
#  2.8141e+05
#  5.3400e+01
#  3.2277e+03
#  1.2376e+03
#  1.1490e+01
#  7.3000e+03
#  6.8663e+00
#  1.1284e+02
#  1.0027e+00
#  6.9561e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9665
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  94.3257
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.1968e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.8543e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.4970e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4680e+05  0.0000e+00  1.4687e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.3163e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  4.4750e+03
#  4.4702e+03
#  9.6198e+05
#  1.2860e+01
#  3.1689e+06
#  7.9000e-01
#  2.0948e+06
#  3.1977e+05
#  3.1560e+05
#  5.3400e+01
#  3.2277e+03
#  1.2376e+03
#  1.1490e+01
#  7.3000e+03
#  6.8663e+00
#  1.1284e+02
#  1.0027e+00
#  6.9665e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9584
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -615.5063
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.2501e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.4778e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.9418e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3026e+05  0.0000e+00  1.5288e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.2387e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  2.2709e+03
#  3.6821e+03
#  9.3088e+05
#  1.0760e+01
#  3.3305e+06
#  1.2200e+00
#  2.1026e+06
#  2.8815e+05
#  2.8446e+05
#  5.3790e+01
#  3.2277e+03
#  1.2373e+03
#  1.1490e+01
#  7.3000e+03
#  6.8666e+00
#  1.1292e+02
#  1.0021e+00
#  6.9584e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -31.1727
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.3881e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9822e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.6048e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.5102e+05  0.0000e+00  1.5184e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.8964e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  3.6644e+03
#  3.1682e+03
#  9.5133e+05
#  1.1510e+01
#  2.9361e+06
#  1.1100e+00
#  1.8351e+06
#  2.5172e+05
#  2.4823e+05
#  5.3970e+01
#  3.1990e+03
#  1.2382e+03
#  1.1490e+01
#  7.2999e+03
#  6.8784e+00
#  1.1328e+02
#  1.0033e+00
#  6.9708e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0072
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -785.3726
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.1321e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.5608e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.0836e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2865e+05  0.0000e+00  1.4511e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.0119e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  8.3955e+03
#  8.9484e+03
#  9.4967e+05
#  1.7120e+01
#  3.2429e+06
#  1.1300e+00
#  2.1214e+06
#  2.8273e+05
#  2.7852e+05
#  5.4060e+01
#  3.2422e+03
#  1.2375e+03
#  1.1570e+01
#  7.2748e+03
#  6.8838e+00
#  1.1367e+02
#  1.0092e+00
#  7.0072e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  160.2494
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.1190e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.4656e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.5754e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4761e+05  0.0000e+00  1.4789e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.4677e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.1673e+04
#  4.8869e+03
#  9.7716e+05
#  1.2280e+01
#  3.0238e+06
#  8.9000e-01
#  2.0668e+06
#  2.7909e+05
#  2.7520e+05
#  5.3590e+01
#  3.2527e+03
#  1.2320e+03
#  1.1740e+01
#  7.3022e+03
#  6.8779e+00
#  1.1342e+02
#  1.0110e+00
#  7.0266e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0506
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -774.4227
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  1.8076e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.6758e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.6701e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2427e+05  0.0000e+00  1.5294e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.1752e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.1753e+04
#  5.3735e+03
#  9.6071e+05
#  1.6130e+01
#  3.0457e+06
#  9.6000e-01
#  2.0849e+06
#  2.8402e+05
#  2.8031e+05
#  5.4450e+01
#  3.2588e+03
#  1.2502e+03
#  1.1710e+01
#  7.2714e+03
#  6.8662e+00
#  1.1269e+02
#  1.0061e+00
#  7.0506e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0688
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -441.7455
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  1.3796e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.7205e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.1444e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2892e+05  0.0000e+00  1.4984e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.8555e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.9598e+04
#  1.7434e+04
#  9.7118e+05
#  1.1980e+01
#  3.2867e+06
#  7.4000e-01
#  2.3814e+06
#  3.2591e+05
#  3.2225e+05
#  5.3990e+01
#  3.2469e+03
#  1.2569e+03
#  1.1470e+01
#  7.2437e+03
#  6.8688e+00
#  1.1213e+02
#  1.0072e+00
#  7.0688e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0548
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -250.6481
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.7876e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.9152e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.8867e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3158e+05  0.0000e+00  1.5998e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.1851e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  6.2384e+03
#  5.1667e+03
#  9.6633e+05
#  2.0870e+01
#  3.6373e+06
#  7.2000e-01
#  2.6290e+06
#  3.5075e+05
#  3.4649e+05
#  5.3990e+01
#  3.2469e+03
#  1.2569e+03
#  1.1470e+01
#  7.2437e+03
#  6.8688e+00
#  1.1213e+02
#  1.0072e+00
#  7.0548e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0623
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -165.5995
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.9605e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.9476e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4440e+05  0.0000e+00  1.7376e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.1240e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  3.5365e+03
#  6.6242e+03
#  9.2175e+05
#  1.0630e+01
#  3.6592e+06
#  1.1400e+00
#  2.5215e+06
#  3.2652e+05
#  3.2303e+05
#  5.3990e+01
#  3.2469e+03
#  1.2569e+03
#  1.1470e+01
#  7.2437e+03
#  6.8691e+00
#  1.1217e+02
#  1.0090e+00
#  7.0623e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0797
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -257.1461
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  5.9969e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.0552e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.5335e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4783e+05  0.0000e+00  1.7227e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.2411e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  4.6408e+03
#  5.3474e+03
#  9.4515e+05
#  1.1000e+01
#  3.9002e+06
#  1.4100e+00
#  2.7259e+06
#  2.6520e+05
#  2.6161e+05
#  5.4050e+01
#  3.2492e+03
#  1.2574e+03
#  1.2090e+01
#  7.2530e+03
#  6.8706e+00
#  1.1274e+02
#  1.0095e+00
#  7.0797e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0837
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  430.8021
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.4483e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.4222e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.4398e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.7201e+05  0.0000e+00  1.7963e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.7728e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  7.5625e+03
#  7.8993e+03
#  9.6823e+05
#  1.2160e+01
#  3.1552e+06
#  9.0000e-01
#  2.3052e+06
#  2.8456e+05
#  2.8062e+05
#  5.4010e+01
#  3.2260e+03
#  1.2526e+03
#  1.2920e+01
#  7.2634e+03
#  6.8675e+00
#  1.1307e+02
#  1.0067e+00
#  7.0837e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0984
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -1271.1560
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  6.8957e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.4961e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.8885e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.1311e+05  0.0000e+00  1.6730e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.9800e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  6.0131e+03
#  4.5133e+03
#  9.7915e+05
#  1.2550e+01
#  3.3524e+06
#  9.9000e-01
#  2.4513e+06
#  3.2541e+05
#  3.2128e+05
#  5.3830e+01
#  3.2401e+03
#  1.2489e+03
#  1.2540e+01
#  7.3829e+03
#  6.8817e+00
#  1.1411e+02
#  1.0103e+00
#  7.0984e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1284
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -171.4914
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.5915e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.6556e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3458e+05  0.0000e+00  1.6336e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.7728e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  7.7627e+03
#  7.0691e+03
#  9.5561e+05
#  1.4380e+01
#  3.1552e+06
#  8.6000e-01
#  2.4160e+06
#  3.1588e+05
#  3.1184e+05
#  5.2610e+01
#  3.2505e+03
#  1.2319e+03
#  1.1810e+01
#  7.3824e+03
#  6.8900e+00
#  1.1435e+02
#  1.0133e+00
#  7.1284e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1502
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -922.6873
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.4215e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.7148e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.1280e+05  0.0000e+00  1.6560e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.5837e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  7.5455e+03
#  1.0685e+04
#  9.8529e+05
#  2.3250e+01
#  3.4401e+06
#  6.4000e-01
#  2.7024e+06
#  3.2943e+05
#  3.2501e+05
#  5.3330e+01
#  3.2192e+03
#  1.2255e+03
#  1.0960e+01
#  7.3743e+03
#  6.8973e+00
#  1.1400e+02
#  1.0076e+00
#  7.1502e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -336.5286
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.0773e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.2435e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2997e+05  0.0000e+00  1.7382e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.8056e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  4.9512e+03
#  6.6299e+03
#  9.8590e+05
#  1.9950e+01
#  3.4587e+06
#  6.4000e-01
#  2.6707e+06
#  3.3731e+05
#  3.3279e+05
#  5.3330e+01
#  3.2192e+03
#  1.2255e+03
#  1.0960e+01
#  7.3743e+03
#  6.8973e+00
#  1.1400e+02
#  1.0076e+00
#  7.1387e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1380
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -673.9943
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.0938e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.9871e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2525e+05  0.0000e+00  1.7729e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.8201e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  3.0260e+03
#  4.9058e+03
#  9.8330e+05
#  2.1140e+01
#  3.0693e+06
#  9.3000e-01
#  2.3179e+06
#  2.6888e+05
#  2.6554e+05
#  5.3330e+01
#  3.2192e+03
#  1.2255e+03
#  1.0960e+01
#  7.3743e+03
#  6.8971e+00
#  1.1385e+02
#  1.0079e+00
#  7.1380e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1512
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -981.5695
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.2622e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.8386e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.1542e+05  0.0000e+00  1.6601e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.5695e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  4.2496e+03
#  3.1228e+03
#  9.6553e+05
#  1.2110e+01
#  3.3670e+06
#  1.1800e+00
#  2.5242e+06
#  2.8074e+05
#  2.7761e+05
#  5.3200e+01
#  3.2173e+03
#  1.2245e+03
#  1.1240e+01
#  7.3501e+03
#  6.8974e+00
#  1.1392e+02
#  1.0122e+00
#  7.1512e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1212
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -132.7065
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.5611e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.9013e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3728e+05  0.0000e+00  1.6772e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.6847e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.4450e+04
#  1.0078e+04
#  9.7486e+05
#  1.3880e+01
#  3.2525e+06
#  8.8000e-01
#  2.4848e+06
#  2.8773e+05
#  2.8372e+05
#  5.3140e+01
#  3.2331e+03
#  1.2151e+03
#  1.1450e+01
#  7.3390e+03
#  6.9025e+00
#  1.1392e+02
#  1.0132e+00
#  7.1212e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0792
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -726.1951
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.0846e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.1139e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2205e+05  0.0000e+00  1.6983e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.2740e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.3399e+04
#  1.0820e+04
#  9.7943e+05
#  1.4030e+01
#  3.5045e+06
#  8.1000e-01
#  2.6099e+06
#  3.2790e+05
#  3.2389e+05
#  5.0280e+01
#  3.2405e+03
#  1.2085e+03
#  1.1860e+01
#  7.3346e+03
#  6.9130e+00
#  1.1441e+02
#  1.0144e+00
#  7.0792e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0719
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -247.8141
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.9275e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.0232e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3716e+05  0.0000e+00  1.7236e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.1756e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  7.6547e+03
#  4.8157e+03
#  9.9180e+05
#  1.3760e+01
#  3.2525e+06
#  7.7000e-01
#  2.2502e+06
#  2.9711e+05
#  2.9329e+05
#  4.9280e+01
#  3.2337e+03
#  1.2024e+03
#  1.2300e+01
#  7.3150e+03
#  6.9112e+00
#  1.1515e+02
#  1.0123e+00
#  7.0719e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0564
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -846.9933
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  9.2897e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.1376e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.6683e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2957e+05  0.0000e+00  1.6619e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.0768e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  3.3468e+04
#  1.3944e+04
#  9.9182e+05
#  1.3190e+01
#  3.3899e+06
#  9.4000e-01
#  2.3991e+06
#  3.0363e+05
#  2.9950e+05
#  4.8490e+01
#  3.2137e+03
#  1.2007e+03
#  1.1660e+01
#  7.3431e+03
#  6.9097e+00
#  1.1475e+02
#  1.0113e+00
#  7.0564e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0570
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -145.5026
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  4.2268e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.0096e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9431e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4184e+05  0.0000e+00  1.6358e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.5968e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  7.3468e+03
#  9.6792e+03
#  9.9758e+05
#  1.0080e+01
#  3.5732e+06
#  8.0000e-01
#  2.3293e+06
#  3.0848e+05
#  3.0433e+05
#  4.8490e+01
#  3.2137e+03
#  1.2007e+03
#  1.1660e+01
#  7.3431e+03
#  6.9097e+00
#  1.1475e+02
#  1.0113e+00
#  7.0570e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0973
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -281.1705
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  1.9848e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.6548e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.1996e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.5579e+05  0.0000e+00  1.6891e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.4619e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.7939e+03
#  3.2493e+03
#  9.6015e+05
#  1.5670e+01
#  3.4128e+06
#  9.9000e-01
#  2.3591e+06
#  2.8068e+05
#  2.7587e+05
#  4.8490e+01
#  3.2137e+03
#  1.2007e+03
#  1.1660e+01
#  7.3431e+03
#  6.9096e+00
#  1.1476e+02
#  1.0098e+00
#  7.0973e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1190
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -323.4806
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  1.3081e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.9182e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.6109e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4258e+05  0.0000e+00  1.6412e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.1772e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.6374e+03
#  6.0075e+03
#  9.8287e+05
#  1.4370e+01
#  3.5503e+06
#  1.2200e+00
#  2.5098e+06
#  2.2111e+05
#  2.1700e+05
#  4.8400e+01
#  3.2094e+03
#  1.2024e+03
#  1.1350e+01
#  7.3671e+03
#  6.9145e+00
#  1.1492e+02
#  1.0076e+00
#  7.1190e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  142.1878
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  5.9516e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.3373e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.7166e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.6005e+05  0.0000e+00  1.7173e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.4337e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.7455e+03
#  2.9819e+03
#  9.6245e+05
#  1.7170e+01
#  3.3212e+06
#  8.2000e-01
#  2.4178e+06
#  2.7308e+05
#  2.6743e+05
#  4.7720e+01
#  3.2352e+03
#  1.2019e+03
#  1.2300e+01
#  7.3579e+03
#  6.9149e+00
#  1.1466e+02
#  1.0095e+00
#  7.1274e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.1325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -660.2421
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  5.5797e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.6432e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.7178e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2950e+05  0.0000e+00  1.6819e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.6872e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  3.9305e+03
#  2.6597e+03
#  9.8398e+05
#  1.5890e+01
#  3.5732e+06
#  8.0000e-01
#  2.6571e+06
#  3.1040e+05
#  3.0517e+05
#  4.8860e+01
#  3.2354e+03
#  1.2038e+03
#  1.1630e+01
#  7.3686e+03
#  6.9144e+00
#  1.1340e+02
#  1.0000e+00
#  7.1325e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0884
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -71.0393
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.8949e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.1835e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4403e+05  0.0000e+00  1.7385e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.9963e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.5247e+04
#  4.5379e+03
#  9.8826e+05
#  1.3780e+01
#  3.2525e+06
#  7.8000e-01
#  2.4466e+06
#  2.9243e+05
#  2.8767e+05
#  4.8750e+01
#  3.2472e+03
#  1.2302e+03
#  1.1210e+01
#  7.4160e+03
#  6.8982e+00
#  1.1335e+02
#  9.9620e-01
#  7.0884e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  7.0212
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -914.1173
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.4498e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.8116e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.2099e+05  0.0000e+00  1.7104e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.1349e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.6705e+04
#  1.3273e+04
#  9.9555e+05
#  1.4250e+01
#  3.5045e+06
#  5.1000e-01
#  2.4700e+06
#  3.2703e+05
#  3.2165e+05
#  4.8780e+01
#  3.2719e+03
#  1.2332e+03
#  1.1280e+01
#  7.4250e+03
#  6.9031e+00
#  1.1269e+02
#  9.9830e-01
#  7.0212e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9196
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -175.3521
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.5378e+03  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.1319e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.6992e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4423e+05  0.0000e+00  1.6905e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  4.4421e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  2.1293e+04
#  1.4678e+04
#  9.4205e+05
#  9.9000e+00
#  3.6417e+06
#  4.5000e-01
#  2.2795e+06
#  2.9220e+05
#  2.8724e+05
#  4.8780e+01
#  3.2719e+03
#  1.2332e+03
#  1.1280e+01
#  7.4250e+03
#  6.9031e+00
#  1.1269e+02
#  9.9830e-01
#  6.9196e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9185
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -36.4490
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.2074e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.7461e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.0348e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.6371e+05  0.0000e+00  1.6551e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.8136e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.2202e+04
#  6.3620e+03
#  8.8906e+05
#  1.0430e+01
#  3.7126e+06
#  5.7000e-01
#  1.9832e+06
#  2.6353e+05
#  2.5850e+05
#  4.8780e+01
#  3.2719e+03
#  1.2332e+03
#  1.1280e+01
#  7.4250e+03
#  6.9033e+00
#  1.1268e+02
#  9.9750e-01
#  6.9185e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9427
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  371.7430
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  4.9888e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.9975e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.3654e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.8507e+05  0.0000e+00  1.5240e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  8.9262e+03  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  7.4979e+03
#  3.1602e+03
#  9.7739e+05
#  8.6100e+00
#  3.9255e+06
#  9.3000e-01
#  2.2671e+06
#  2.7124e+05
#  2.6628e+05
#  4.8220e+01
#  3.2411e+03
#  1.2372e+03
#  1.1340e+01
#  7.4298e+03
#  6.9085e+00
#  1.1258e+02
#  9.9890e-01
#  6.9427e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9891
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  760.7824
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  4.8043e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.5999e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.9444e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.9559e+05  0.0000e+00  1.6119e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.2706e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.1126e+04
#  4.4981e+03
#  9.8200e+05
#  1.1940e+01
#  3.2161e+06
#  6.6000e-01
#  1.9485e+06
#  2.7703e+05
#  2.7281e+05
#  4.7340e+01
#  3.2502e+03
#  1.2496e+03
#  1.2470e+01
#  7.3783e+03
#  6.8872e+00
#  1.1154e+02
#  9.9340e-01
#  6.9891e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -801.1908
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  4.0991e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.1599e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  3.8110e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.3896e+05  0.0000e+00  1.5155e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.3215e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.4521e+04
#  7.6875e+03
#  9.8210e+05
#  1.0300e+01
#  3.3579e+06
#  6.6000e-01
#  2.1886e+06
#  2.8806e+05
#  2.8312e+05
#  4.8040e+01
#  3.2462e+03
#  1.2528e+03
#  1.2810e+01
#  7.3247e+03
#  6.8829e+00
#  1.1137e+02
#  9.9210e-01
#  6.9443e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.9439
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  199.2220
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  2.2970e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.7459e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.5859e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.5388e+05  0.0000e+00  1.5156e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  3.4872e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.9170e+03
#  3.3683e+03
#  9.6509e+05
#  1.3300e+01
#  3.8072e+06
#  6.1000e-01
#  2.2480e+06
#  3.2071e+05
#  3.1524e+05
#  4.7700e+01
#  3.2458e+03
#  1.2501e+03
#  1.3120e+01
#  7.3407e+03
#  6.8860e+00
#  1.1100e+02
#  9.9330e-01
#  6.9439e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.8841
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  301.3258
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.7618e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  7.6888e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.2549e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.7931e+05  0.0000e+00  1.6300e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.5494e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.6072e+04
#  1.3798e+04
#  8.6994e+05
#  1.0940e+01
#  3.4998e+06
#  6.9000e-01
#  2.0765e+06
#  2.8787e+05
#  2.8235e+05
#  4.7970e+01
#  3.2474e+03
#  1.2517e+03
#  1.2960e+01
#  7.3368e+03
#  6.8839e+00
#  1.1135e+02
#  9.9140e-01
#  6.8841e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.8278
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -43.6247
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  3.5910e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.0804e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.6332e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.5701e+05  0.0000e+00  1.5029e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.7817e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.3507e+04
#  1.1426e+04
#  9.3992e+05
#  6.7500e+00
#  4.1619e+06
#  5.7000e-01
#  2.1898e+06
#  2.8952e+05
#  2.8372e+05
#  4.7970e+01
#  3.2474e+03
#  1.2517e+03
#  1.2960e+01
#  7.3368e+03
#  6.8839e+00
#  1.1135e+02
#  9.9140e-01
#  6.8278e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  6.8774
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1774.8247
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  5.5385e+04  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    8.8982e+03  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  9.6942e+04
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.7958e+04  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  2.1992e+05  0.0000e+00  1.5913e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  5.4926e+03  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  9.0129e+03
#  5.2261e+03
#  6.7674e+05
#  9.5500e+00
#  3.1451e+06
#  5.5000e-01
#  1.6967e+06
#  2.4298e+05
#  2.3839e+05
#  4.7970e+01
#  3.2474e+03
#  1.2517e+03
#  1.2960e+01
# ...
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.2976e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  2.1527e+05  2.3192e+04  2.7633e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  7.7402e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.6996e+04
#  2.6229e+04
#  8.8123e+05
#  6.5900e+00
#  7.6544e+06
#  5.6000e-01
#  6.5538e+06
#  2.3579e+05
#  2.2931e+05
#  4.9580e+01
#  3.2693e+03
#  1.2646e+03
#  1.0030e+01
#  7.5117e+03
#  6.7287e+00
#  1.1068e+02
#  9.7280e-01
#  8.0612e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.0821
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  4133.4272
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.9552e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  3.1768e+05  1.3696e+04  3.1943e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  8.8887e+04  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  5.9987e+03
#  1.3288e+04
#  7.8643e+05
#  1.0370e+01
#  7.5689e+06
#  7.6000e-01
#  7.2552e+06
#  2.3977e+05
#  2.3277e+05
#  4.9580e+01
#  3.2693e+03
#  1.2646e+03
#  1.0030e+01
#  7.5117e+03
#  6.7288e+00
#  1.1078e+02
#  9.7250e-01
#  8.0821e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.1135
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3231.1152
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.8853e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  2.4671e+05  4.3397e+04  3.5237e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.3571e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.2046e+04
#  1.3877e+04
#  9.4370e+05
#  1.2420e+01
#  5.9867e+06
#  5.7000e-01
#  5.8026e+06
#  1.9963e+05
#  1.9346e+05
#  4.9390e+01
#  3.2577e+03
#  1.2647e+03
#  9.9300e+00
#  7.5319e+03
#  6.7213e+00
#  1.1075e+02
#  9.7350e-01
#  8.1135e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.1355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  541.2614
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.4083e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.7574e+05  3.3884e+04  3.0944e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.0793e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.5835e+04
#  1.8412e+04
#  9.7925e+05
#  7.7000e+00
#  6.5426e+06
#  5.0000e-01
#  6.7003e+06
#  2.4900e+05
#  2.4112e+05
#  4.9170e+01
#  3.2772e+03
#  1.2626e+03
#  1.0960e+01
#  7.5427e+03
#  6.7066e+00
#  1.1010e+02
#  9.7280e-01
#  8.1355e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.1061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  2454.4590
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.8081e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  2.1220e+05  3.2840e+04  3.1947e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.3679e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.4287e+04
#  1.1414e+04
#  9.5448e+05
#  1.2050e+01
#  7.0129e+06
#  6.1000e-01
#  7.3953e+06
#  2.7557e+05
#  2.6570e+05
#  4.9560e+01
#  3.2778e+03
#  1.2793e+03
#  1.1110e+01
#  7.4981e+03
#  6.6741e+00
#  1.0995e+02
#  9.6360e-01
#  8.1061e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.1300
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1762.5079
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.9561e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  2.0615e+05  3.5335e+04  3.5223e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.5887e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  9.0311e+03
#  8.9445e+03
#  9.8128e+05
#  1.1690e+01
#  6.3334e+06
#  7.8000e-01
#  6.1170e+06
#  2.6096e+05
#  2.5317e+05
#  4.8590e+01
#  3.2697e+03
#  1.2901e+03
#  1.6040e+01
#  7.3899e+03
#  6.6476e+00
#  1.0915e+02
#  9.6250e-01
#  8.1300e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.1639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  274.7641
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.6048e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.9369e+05  2.2361e+04  3.2139e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.1369e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.1927e+04
#  1.4064e+04
#  9.6717e+05
#  1.3160e+01
#  6.1498e+06
#  6.6000e-01
#  6.1639e+06
#  2.5796e+05
#  2.4980e+05
#  4.8820e+01
#  3.2379e+03
#  1.2940e+03
#  1.5510e+01
#  7.3100e+03
#  6.6645e+00
#  1.0919e+02
#  9.6190e-01
#  8.1639e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.2399
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1653.1522
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.6236e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.9182e+05  3.2109e+04  3.0829e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.2571e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.2351e+04
#  1.7519e+04
#  9.7992e+05
#  1.1930e+01
#  6.6088e+06
#  7.4000e-01
#  7.1306e+06
#  2.8400e+05
#  2.7351e+05
#  4.8820e+01
#  3.2379e+03
#  1.2940e+03
#  1.5510e+01
#  7.3100e+03
#  6.6645e+00
#  1.0919e+02
#  9.6190e-01
#  8.2399e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.2958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1647.2596
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.8753e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.8839e+05  3.5629e+04  3.3766e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.6118e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.5890e+04
#  2.8098e+04
#  9.8332e+05
#  1.9450e+01
#  6.1957e+06
#  8.4000e-01
#  7.0680e+06
#  2.6052e+05
#  2.5244e+05
#  4.8820e+01
#  3.2379e+03
#  1.2940e+03
#  1.5510e+01
#  7.3100e+03
#  6.6647e+00
#  1.0916e+02
#  9.6240e-01
#  8.2958e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3453
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  500.9537
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.7772e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4880e+05  4.0926e+04  3.4098e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.6815e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.4212e+04
#  1.7768e+04
#  9.5526e+05
#  8.4400e+00
#  6.7923e+06
#  9.0000e-01
#  8.1480e+06
#  2.6331e+05
#  2.5461e+05
#  4.7590e+01
#  3.2060e+03
#  1.2904e+03
#  1.2330e+01
#  7.3539e+03
#  6.6713e+00
#  1.0975e+02
#  9.7210e-01
#  8.3453e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3191
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1282.4917
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  9.1484e+03
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.1300e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.6552e+05  4.7378e+04  3.6526e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  1.9748e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  2.5516e+04
#  2.8087e+04
#  9.7507e+05
#  1.7370e+01
#  5.9662e+06
#  9.1000e-01
#  7.7822e+06
#  2.5536e+05
#  2.4707e+05
#  4.7550e+01
#  3.2352e+03
#  1.2797e+03
#  1.2040e+01
#  7.3839e+03
#  6.6856e+00
#  1.1064e+02
#  9.7230e-01
#  8.3191e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -1940.9618
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.0973e+04
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.8647e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  9.5545e+04  5.4246e+04  3.5951e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.0939e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.2924e+04
#  1.7563e+04
#  9.6673e+05
#  1.5050e+01
#  6.9759e+06
#  7.8000e-01
#  9.1467e+06
#  3.1100e+05
#  3.0044e+05
#  4.6780e+01
#  3.2479e+03
#  1.2829e+03
#  1.1740e+01
#  7.4330e+03
#  6.6914e+00
#  1.1009e+02
#  9.6510e-01
#  8.3413e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -882.0287
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  4.5172e+04
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.4026e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4309e+05  4.4870e+04  3.8671e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.3713e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.4573e+04
#  2.2062e+04
#  9.7874e+05
#  1.4250e+01
#  5.9662e+06
#  8.7000e-01
#  8.3206e+06
#  2.7487e+05
#  2.6696e+05
#  4.7090e+01
#  3.2539e+03
#  1.2924e+03
#  1.5550e+01
#  7.3879e+03
#  6.6754e+00
#  1.0946e+02
#  9.6280e-01
#  8.3753e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3381
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -3708.1130
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  6.4225e+04
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.0062e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  7.2692e+04  5.4608e+04  3.7621e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.3135e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.7517e+04
#  1.8513e+04
#  9.5999e+05
#  8.6500e+00
#  8.2151e+06
#  8.5000e-01
#  1.0850e+07
#  3.4732e+05
#  3.3706e+05
#  4.8510e+01
#  3.2532e+03
#  1.2916e+03
#  1.4260e+01
#  7.3240e+03
#  6.6710e+00
#  1.0918e+02
#  9.6480e-01
#  8.3381e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3017
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -113.4687
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  5.5918e+04
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.9522e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.8368e+05  4.7845e+04  4.3711e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.7732e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  1.5036e+04
#  2.5191e+04
#  9.6646e+05
#  1.4420e+01
#  6.8382e+06
#  7.9000e-01
#  8.7751e+06
#  3.1225e+05
#  3.0146e+05
#  4.8510e+01
#  3.2532e+03
#  1.2916e+03
#  1.4260e+01
#  7.3240e+03
#  6.6710e+00
#  1.0918e+02
#  9.6480e-01
#  8.3017e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.3075
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
# -2509.0527
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.7432e+04
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.1497e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.0503e+05  4.5107e+04  4.0891e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.2456e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]
#
# Variable containing:
#  6.2380e+03
#  8.9437e+03
#  9.6145e+05
#  9.9100e+00
#  6.9300e+06
#  6.8000e-01
#  8.7684e+06
#  2.6683e+05
#  2.5834e+05
#  4.8510e+01
#  3.2532e+03
#  1.2916e+03
#  1.4260e+01
#  7.3240e+03
#  6.6712e+00
#  1.0941e+02
#  9.6530e-01
#  8.3075e+00
# [torch.cuda.FloatTensor of size 18 (GPU 0)]
#
# Variable containing:
#  8.2960
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  3.5787
# [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#
# Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 5
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.6051e+04
#
# Columns 6 to 11
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
#
# Columns 12 to 17
#    0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  2.3042e+05  0.0000e+00
#
# Columns 18 to 23
#    0.0000e+00  0.0000e+00  0.0000e+00  1.4872e+05  5.1220e+04  3.8718e+05
#
# Columns 24 to 29
#    0.0000e+00  0.0000e+00  2.1443e+05  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.cuda.FloatTensor of size 1x1x30 (GPU 0)]

# %%
plt.figure
plt.plot(np.exp(real))
plt.plot(np.exp(predict))
plt.show()
# Out:
# /home/tako/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
real[800:810]
# Out:
# [6.9235892,
#  6.9287629,
#  6.9503355,
#  6.9523749,
#  6.9043593,
#  6.8851619,
#  6.9159122,
#  6.9100924,
#  6.9022098,
#  6.9143934]

# %%
predict[800:810]
# Out:
# [-679.74023,
#  -344.0141,
#  -69.089867,
#  -1204.6417,
#  193.05284,
#  -678.11597,
#  177.77139,
#  -849.86151,
#  -278.21655,
#  -133.78519]

# %%
MAPE = np.sum([np.abs((np.exp(real)-np.exp(predict)))/np.exp(predict)])/len(real)
# Out:
# /home/tako/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in exp
#   """Entry point for launching an IPython kernel.
# /home/tako/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /home/tako/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
MAPE
# Out:
# nan
